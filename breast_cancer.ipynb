# %%
# !pip install kaggle
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ...
# Mounted at /content/drive

# %%
mkdir /root/.kaggle

# %%
# !cp /content/drive/MyDrive/Kaggle/kaggle.json ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# %cd '/content/drive/MyDrive/Kaggle'
# Out:
# /content/drive/MyDrive/Kaggle

# %% [markdown]
# IMPORT DATASET

# %%
import pandas as pd
df=pd.read_csv('breast_cancer_data.csv')
df
# Out:
#            id diagnosis  Radius_mean  Texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         21.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.head()
# Out:
#          id diagnosis  Radius_mean  Texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         21.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'Radius_mean', 'Texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df.shape
# Out:
# (569, 32)

# %% [markdown]
# DATA VISUALIZATION

# %%
#let us draw a countplot of our target variable Diagnosis
import matplotlib.pyplot as plt
import seaborn as sns
import os

sns.countplot(x='diagnosis',data=df)
plt.show()

# %%
#pair according to diagnosis
sns.pairplot(df.iloc[:,1:6],hue='diagnosis')
plt.show()

# %%
#let us plot the heatmap ie correlation matrix
plt.figure(figsize=(30,25))
sns.heatmap(df.corr())
ax=sns.heatmap(df.corr(),vmin=-1,vmax=1,center=0,annot=True)
plt.show()
# Out:
# <ipython-input-11-52576d260eff>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <ipython-input-11-52576d260eff>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ax=sns.heatmap(df.corr(),vmin=-1,vmax=1,center=0,annot=True)

# %%
#encoding the diagnosis feature
df.replace({'diagnosis':{'M':1,'B':0}},inplace=True)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

selected_features=['Radius_mean', 'Texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst','diagnosis','id']

#let us create a new dataframe with only the above features
top_feature_df=df[selected_features]

#correlation matrix
corr_matrix=top_feature_df.corr()

#sort the correlation values with respect to diagnosis column
sorted_corr=corr_matrix['diagnosis'].sort_values(ascending=False)

#pick the top 10 features
top_features=sorted_corr.head(31)

#new dataframe with these values only
best_df=top_feature_df[top_features.index]

#correlation matrix
top_features_corr=best_df.corr()

#set up the matplot heat map
plt.figure(figsize=(20,25))

sns.heatmap(top_features_corr, annot=True, cmap='coolwarm', linewidth=0.5)

plt.title('Top Feature Correlation With Diagnosis')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

selected_features=['Radius_mean', 'Texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst','diagnosis']

#let us create a new dataframe with only the above features
top_feature_df=df[selected_features]

#correlation matrix
corr_matrix=top_feature_df.corr()

#sort the correlation values with respect to diagnosis column
sorted_corr=corr_matrix['diagnosis'].sort_values(ascending=False)

#pick the top 10 features
top_features=sorted_corr.head(6)

#new dataframe with these values only
best_df=top_feature_df[top_features.index]

#correlation matrix
top_features_corr=best_df.corr()

#set up the matplot heat map
plt.figure(figsize=(12,10))

sns.heatmap(top_features_corr, annot=True, cmap='coolwarm', linewidth=0.5)

plt.title('Top Feature Correlation With Diagnosis')
plt.show()

# %%
#Let us whether the dataset has a normal distribution or not according to diagnosis
sns.displot(data=df,
            x='Radius_mean',
            hue='diagnosis',
            kind='kde',
            fill=True,
            height=5,
            aspect=1.5)

# %% [markdown]
# DATA PREPROCESSING

# %%
#preprocessing the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    int64
#  2   Radius_mean              569 non-null    float64
#  3   Texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.isnull()
# Out:
#         id  diagnosis  Radius_mean  Texture_mean  perimeter_mean  area_mean  \
# 0    False      False        False         False           False      False
# 1    False      False        False         False           False      False
# 2    False      False        False         False           False      False
# 3    False      False        False         False           False      False
# 4    False      False        False         False           False      False
# ..     ...        ...          ...           ...             ...        ...
# 564  False      False        False         False           False      False
# 565  False      False        False         False           False      False
# 566  False      False        False         False           False      False
# 567  False      False        False         False           False      False
# 568  False      False        False         False           False      False
#
# ...

# %%
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# Radius_mean                0
# Texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
#There are no null values

# %%
df['diagnosis']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %%
#define dependent variable and independent variable
X=df.drop(columns={'diagnosis','id'},axis=1)
y=df['diagnosis']

# %%
#independent variable
X
# Out:
#      Radius_mean  Texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         21.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
#Dependent variable
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %%
#let us split the traing and testing data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,stratify=y,random_state=1)

# %%
X_train
# Out:
#      Radius_mean  Texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 195        12.91         16.33           82.53      516.4          0.07941
# 560        14.05         27.15           91.38      600.4          0.09929
# 544        13.87         20.70           89.77      584.8          0.09578
# 495        14.87         20.21           96.12      680.9          0.09587
# 527        12.34         12.27           78.94      468.5          0.09003
# ..           ...           ...             ...        ...              ...
# 406        16.14         14.86          104.30      800.0          0.09495
# 164        23.27         22.04          152.10     1686.0          0.08439
# 536        14.27         22.55           93.77      629.8          0.10380
# 219        19.53         32.47          128.00     1223.0          0.08420
# 284        12.89         15.70           84.08      516.6          0.07818
#
# ...

# %%
y_train
# Out:
# 195    0
# 560    0
# 544    0
# 495    0
# 527    0
#       ..
# 406    0
# 164    1
# 536    1
# 219    1
# 284    0
# Name: diagnosis, Length: 455, dtype: int64

# %% [markdown]
# Let us Apply Predictive Models

# %%
#let us standardize the data
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
#DecisionTree Model
seed_value=42
from sklearn.tree import DecisionTreeClassifier
decision_classifier=DecisionTreeClassifier(random_state=seed_value)

# %%
decision_classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred=decision_classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,y_pred)

# %%
print("Accuracy=",accuracy)
# Out:
# Accuracy= 0.9210526315789473

# %%
from sklearn.metrics import classification_report
classification_ans=classification_report(y_test,y_pred)
print(classification_ans)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94        72
#            1       0.90      0.88      0.89        42
#
#     accuracy                           0.92       114
#    macro avg       0.92      0.91      0.91       114
# weighted avg       0.92      0.92      0.92       114

# %%
#we can calculate the error rate
misclassifications=(y_pred!=y_test).sum()

# %%
error_rate=(misclassifications/len(y_test))*100

# %%
print("Error rate: ",error_rate)
# Out:
# Error rate:  7.894736842105263

# %%
#Alternate method to get error rate
error_rate=(1-accuracy)*100
print("Error Rate: ",error_rate,"in percentage")
# Out:
# Error Rate:  7.8947368421052655 in percentage

# %%
#Logistic Regeression

# %%
import numpy as np
np.random.seed(42)
from sklearn.linear_model import LogisticRegression
seed_value=42
log_reger=LogisticRegression(
    solver='lbfgs',
    max_iter=100,
    C=1.0,
    random_state=seed_value)
#solver will specifies the optimization algorithm to use
#max_iter sets the maximum number of iterations for the solver to converge
#C controls the regularization strength

# %%
log_reger.fit(X_train,y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
y_pred=log_reger.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,y_pred)

# %%
print("Accuracy: ",accuracy)
# Out:
# Accuracy:  0.9824561403508771

# %%
from sklearn.metrics import classification_report
classification=classification_report(y_test,y_pred)

# %%
print(classification)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        72
#            1       0.98      0.98      0.98        42
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %%
error_rate=(1-accuracy)*100
print("Error Rate: ",error_rate)
# Out:
# Error Rate:  1.7543859649122862

# %%
#let us apply KNN model to it

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_classifier=KNeighborsClassifier(n_neighbors=3,metric='manhattan')
knn_classifier.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=3)

# %%
y_pred=knn_classifier.predict(X_test)

# %%
accuracy=accuracy_score(y_test,y_pred)

# %%
print("Accuracy: ",accuracy)
# Out:
# Accuracy:  0.9473684210526315

# %%
error_rate=(1-accuracy)*100
print("Error Rate: ",error_rate)
# Out:
# Error Rate:  5.263157894736848

# %%
from sklearn.metrics import classification_report
classification=classification_report(y_test,y_pred)

# %%
print(classification)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96        72
#            1       0.95      0.90      0.93        42
#
#     accuracy                           0.95       114
#    macro avg       0.95      0.94      0.94       114
# weighted avg       0.95      0.95      0.95       114

# %%
from sklearn.ensemble import RandomForestClassifier
seed_value=42
random_classifier=RandomForestClassifier(random_state=seed_value)

# %%
random_classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred=random_classifier.predict(X_test)

# %%
accuracy_random_whole=accuracy_score(y_test,y_pred)

# %%
print("Accuracy: ",accuracy_random_whole)
# Out:
# Accuracy:  0.956140350877193

# %%
from sklearn.metrics import classification_report
classification=classification_report(y_test,y_pred)

# %%
print(classification)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97        72
#            1       0.97      0.90      0.94        42
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %%
error_rate=(1-accuracy)*100
print("Error Rate: ",error_rate)
# Out:
# Error Rate:  5.263157894736848

# %%
#let us apply svm model

# %%
from sklearn.svm import SVC
seed_value=42
svm_classifier=SVC(kernel="linear",random_state=seed_value)
svm_classifier.fit(X_train,y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
y_pred=svm_classifier.predict(X_test)

# %%
accuracy_svm_whole=accuracy_score(y_test,y_pred)

# %%
print("Accuracy: ",accuracy_svm_whole)
# Out:
# Accuracy:  0.9649122807017544

# %%
classification=classification_report(y_test,y_pred)

# %%
print(classification)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        72
#            1       0.95      0.95      0.95        42
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.96      0.96       114
# weighted avg       0.96      0.96      0.96       114

# %%
error_rate=(1-accuracy)*100
print("Error Rate: ",error_rate)
# Out:
# Error Rate:  5.263157894736848

# %%
#let us apply ANN

# %%
#let us now Arrificial Neural Network
import tensorflow as tf
import numpy as np
import random
from tensorflow import keras
seed_value=42
input_dim=X_train.shape[1]
num_classes=2

# Set random seeds for reproducibility
seed_value = 42
tf.random.set_seed(seed_value)
np.random.seed(seed_value)
random.seed(seed_value)


model = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(input_dim,), name='input_layer'),
    keras.layers.Dense(128, activation='relu', name='hidden_layer_1'),
    keras.layers.Dense(num_classes, activation='softmax', name='output_layer')
])
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X_train,y_train, epochs=15, batch_size=32, validation_data=(X_test,y_test),verbose=2)
# Out:
# Epoch 1/15
# 15/15 - 1s - loss: 0.4350 - accuracy: 0.8462 - val_loss: 0.2281 - val_accuracy: 0.9298 - 1s/epoch - 96ms/step
# Epoch 2/15
# 15/15 - 0s - loss: 0.1712 - accuracy: 0.9473 - val_loss: 0.1238 - val_accuracy: 0.9561 - 64ms/epoch - 4ms/step
# Epoch 3/15
# 15/15 - 0s - loss: 0.1111 - accuracy: 0.9670 - val_loss: 0.0902 - val_accuracy: 0.9649 - 96ms/epoch - 6ms/step
# Epoch 4/15
# 15/15 - 0s - loss: 0.0841 - accuracy: 0.9780 - val_loss: 0.0765 - val_accuracy: 0.9649 - 74ms/epoch - 5ms/step
# Epoch 5/15
# 15/15 - 0s - loss: 0.0695 - accuracy: 0.9890 - val_loss: 0.0698 - val_accuracy: 0.9737 - 88ms/epoch - 6ms/step
# Epoch 6/15
# 15/15 - 0s - loss: 0.0594 - accuracy: 0.9912 - val_loss: 0.0649 - val_accuracy: 0.9737 - 94ms/epoch - 6ms/step
# Epoch 7/15
# 15/15 - 0s - loss: 0.0525 - accuracy: 0.9912 - val_loss: 0.0642 - val_accuracy: 0.9737 - 69ms/epoch - 5ms/step
# Epoch 8/15
# ...

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0633 - accuracy: 0.9649
# Test Accuracy: 0.9649122953414917

# %%
error_rate_ann_whole=(1-test_accuracy)*100
print("Error Rate: ",error_rate_ann_whole)
# Out:
# Error Rate:  3.50877046585083

# %%
predictions_whole=model.predict(X_test)
predicted_classes_whole = np.argmax(predictions_whole, axis=1)
print(classification_report(y_test,predicted_classes_whole))
# Out:
# 4/4 [==============================] - 0s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        72
#            1       0.95      0.95      0.95        42
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.96      0.96       114
# weighted avg       0.96      0.96      0.96       114

# %% [markdown]
# Tuning of hyperparameters of Logistic Regression Model

# %%
#we had find that the Logistic regression model has the best accuracy. Let us tune the hyperparametrs of this model

# %%
param_grid={
    'C':[0.001,0.01,0.1,1,10,100],
    'penalty':['l1','l2'],
    'solver':['lbfgs','liblinear']
}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
log_reger_model=LogisticRegression()

# %%
grid_search=GridSearchCV(
    estimator=log_reger_model,
    param_grid=param_grid,
    scoring='accuracy',
    cv=5
)

# %%
grid_search.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
best_parameters=grid_search.best_params_
best_score=grid_search.best_score_

# %%
best_model=LogisticRegression(**best_parameters)

# %%
best_model.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1, solver='liblinear')

# %%
accuracy=best_model.score(X_test,y_test)

# %%
print("Accuracy By tuning Logistic Regression Model is: ",accuracy)
# Out:
# Accuracy By tuning Logistic Regression Model is:  0.9824561403508771

# %%
#Let us use randomized search method to tune it
from sklearn.model_selection import RandomizedSearchCV
random_search=RandomizedSearchCV(
    estimator=log_reger_model,
    param_distributions=param_grid,
    n_iter=50,
    scoring='accuracy',
    cv=5
)

# %%
random_search.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:305: UserWarning: The total space of parameters 24 is smaller than n_iter=50. Running 24 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# ...

# %%
best_params=random_search.best_params_
best_score=random_search.best_score_

# %%
best_log_model=LogisticRegression(**best_params)
best_log_model.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1, solver='liblinear')

# %%
accuracy=best_log_model.score(X_test,y_test)
print("Accuracy: ",accuracy)
# Out:
# Accuracy:  0.9824561403508771

# %%
#So atlast we can conclude that the Logistic Regression model gives best accuracy to the dataset

# %%
#let us give top features alone and create a data frame
top_selected_features=['perimeter_mean','concave points_mean','radius_worst','perimeter_worst',
'concave points_worst','diagnosis']
new_df=df[top_selected_features]

# %%
new_df
# Out:
#      perimeter_mean  concave points_mean  radius_worst  perimeter_worst  \
# 0            122.80              0.14710        25.380           184.60
# 1            132.90              0.07017        24.990           158.80
# 2            130.00              0.12790        23.570           152.50
# 3             77.58              0.10520        14.910            98.87
# 4            135.10              0.10430        22.540           152.20
# ..              ...                  ...           ...              ...
# 564          142.00              0.13890        25.450           166.10
# 565          131.20              0.09791        23.690           155.00
# 566          108.30              0.05302        18.980           126.70
# 567          140.10              0.15200        25.740           184.60
# 568           47.92              0.00000         9.456            59.16
#
#      concave points_worst  diagnosis
# 0                  0.2654          1
# ...

# %%
top_X=new_df.drop('diagnosis', axis=1)
top_y=new_df['diagnosis']

# %%
from sklearn.model_selection import train_test_split

top_X_train,top_X_test,top_y_train,top_y_test=train_test_split(top_X,top_y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
top_X_train=scaler.fit_transform(top_X_train)
top_X_test=scaler.transform(top_X_test)

# %%
#DECISION TREE
from sklearn.tree import DecisionTreeClassifier
seed_value=42
Dtree=DecisionTreeClassifier(random_state=seed_value)
Dtree.fit(top_X_train,top_y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
top_Dtree_y_pred=Dtree.predict(top_X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report
top_DTree_accuracy=accuracy_score(top_y_test,top_Dtree_y_pred)
top_DTree_classification=classification_report(top_y_test,top_Dtree_y_pred)

# %%
print("Acuuracy: ",top_DTree_accuracy)
print("Classifiaction: ",top_DTree_classification)
# Out:
# Acuuracy:  0.9385964912280702
# Classifiaction:                precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95        71
#            1       0.93      0.91      0.92        43
#
#     accuracy                           0.94       114
#    macro avg       0.94      0.93      0.93       114
# weighted avg       0.94      0.94      0.94       114

# %%
  #Error Rate
  top_Dtree_error=(1-top_DTree_accuracy)*100
  print("Error Rate: ",top_Dtree_error)
# Out:
# Error Rate:  6.140350877192979

# %%
from sklearn.ensemble import RandomForestClassifier
seed_value=42
Rforest=RandomForestClassifier(random_state=seed_value)
Rforest.fit(top_X_train,top_y_train)
top_rf_y_pred=Rforest.predict(top_X_test)
top_rf_accuracy=accuracy_score(top_y_test,top_rf_y_pred)
top_rf_classification=classification_report(top_y_test,top_rf_y_pred)

# %%
print("Accuracy of Random Forest Classifier by combining the top features: ",top_rf_accuracy)
print("Classification Report of Random Forest Classifier by combining the top features: ")
print(top_rf_classification)
top_rf_error_rate=(1-top_rf_accuracy)*100
print("Error Rate: ",top_rf_error_rate,"in percentage")
# Out:
# Accuracy of Random Forest Classifier by combining the top features:  0.9473684210526315
# Classification Report of Random Forest Classifier by combining the top features:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96        71
#            1       0.95      0.91      0.93        43
#
#     accuracy                           0.95       114
#    macro avg       0.95      0.94      0.94       114
# weighted avg       0.95      0.95      0.95       114
#
# Error Rate:  5.263157894736848 in percentage

# %%
#SVM
from sklearn.svm import SVC
new_svm_classifier=SVC(kernel='linear',random_state=42)
new_svm_classifier.fit(top_X_train,top_y_train)
top_svm_y_pred=new_svm_classifier.predict(top_X_test)
top_svm_accuracy=accuracy_score(top_y_test,top_svm_y_pred)
top_svm_classification=classification_report(top_y_test,top_svm_y_pred)

# %%
print("Accuracy of SVM by combining the top features: ",top_svm_accuracy)
print("Classification Report of SVMby combining the top features: ")
print(top_svm_classification)
top_svm_error_rate=(1-top_svm_accuracy)*100
print("Error Rate: ",top_svm_error_rate,"in percentage")
# Out:
# Accuracy of SVM by combining the top features:  0.9649122807017544
# Classification Report of SVMby combining the top features:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        71
#            1       0.95      0.95      0.95        43
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.96      0.96       114
# weighted avg       0.96      0.96      0.96       114
#
# Error Rate:  3.508771929824561 in percentage

# %%
import numpy as np
np.random.seed(42)
from sklearn.linear_model import LogisticRegression
seed_value=42
top_log_reger=LogisticRegression(
    solver='lbfgs',
    max_iter=100,
    C=1.0,
    random_state=seed_value)

# %%
top_log_reger.fit(top_X_train,top_y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
top_log_y_pred=top_log_reger.predict(top_X_test)

# %%
top_log_accuracy=accuracy_score(top_y_test,top_log_y_pred)
print("Accuracy",top_log_accuracy)
top_log_classification=classification_report(top_y_test,top_log_y_pred)
print("Classification Report of Log reger by combining the top features: ")
print(top_log_classification)
top_log_error_rate=(1-top_log_accuracy)*100
print("Error Rate: ",top_log_error_rate,"in percentage")
# Out:
# Accuracy 0.9736842105263158
# Classification Report of Log reger by combining the top features:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98        71
#            1       0.95      0.98      0.97        43
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
# Error Rate:  2.631578947368418 in percentage

# %%
#KNN CLASSIFIER
from sklearn.neighbors import KNeighborsClassifier
seed_value=42

top_new_knn=KNeighborsClassifier(n_neighbors=3,metric='manhattan')
top_new_knn.fit(top_X_train,top_y_train)
top_knn_y_pred=top_new_knn.predict(top_X_test)

# %%
top_knn_accuracy=accuracy_score(top_y_test,top_knn_y_pred)
top_knn_classification=classification_report(top_y_test,top_knn_y_pred)
print("The accuracy of KNN is: ",top_knn_accuracy)
print("Classification report of KNN is: ")
print(top_knn_classification)
top_knn_error_rate=(1-top_knn_accuracy)*100
print("The error rate of Knn is: ",top_knn_error_rate,"in percentage")
# Out:
# The accuracy of KNN is:  0.956140350877193
# Classification report of KNN is:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97        71
#            1       0.95      0.93      0.94        43
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
# The error rate of Knn is:  4.385964912280704 in percentage

# %%
#ANN
import numpy as np
import tensorflow as tf
import random
from tensorflow import keras

seed_value=42
tf.random.set_seed(seed_value)
np.random.seed(seed_value)

#Defining the neural network
input_dim=top_X_train.shape[1]
num_classes=2

new_model=keras.Sequential([
      keras.layers.Dense(64,activation='relu',input_shape=(input_dim,), name='input_layer'),
      keras.layers.Dropout(0.5),
      keras.layers.Dense(128,activation='relu', name='hidden_layer_1'),
      keras.layers.Dropout(0.5),
      keras.layers.Dense(num_classes, activation='softmax',name='output_layer')
])

# %%
#compiling the model
new_model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
new_model.fit(top_X_train,top_y_train, epochs=10, batch_size=32, validation_data=(top_X_test,top_y_test),verbose=2)
# Out:
# Epoch 1/10
# 15/15 - 1s - loss: 0.6089 - accuracy: 0.6835 - val_loss: 0.3291 - val_accuracy: 0.9737 - 1s/epoch - 84ms/step
# Epoch 2/10
# 15/15 - 0s - loss: 0.3106 - accuracy: 0.9165 - val_loss: 0.1797 - val_accuracy: 0.9737 - 89ms/epoch - 6ms/step
# Epoch 3/10
# 15/15 - 0s - loss: 0.2255 - accuracy: 0.9429 - val_loss: 0.1218 - val_accuracy: 0.9737 - 160ms/epoch - 11ms/step
# Epoch 4/10
# 15/15 - 0s - loss: 0.1932 - accuracy: 0.9275 - val_loss: 0.0981 - val_accuracy: 0.9737 - 117ms/epoch - 8ms/step
# Epoch 5/10
# 15/15 - 0s - loss: 0.1902 - accuracy: 0.9253 - val_loss: 0.0867 - val_accuracy: 0.9649 - 107ms/epoch - 7ms/step
# Epoch 6/10
# 15/15 - 0s - loss: 0.1670 - accuracy: 0.9429 - val_loss: 0.0807 - val_accuracy: 0.9649 - 74ms/epoch - 5ms/step
# Epoch 7/10
# 15/15 - 0s - loss: 0.1463 - accuracy: 0.9429 - val_loss: 0.0780 - val_accuracy: 0.9737 - 81ms/epoch - 5ms/step
# Epoch 8/10
# ...

# %%
top_test_loss,top_test_accuracy =new_model.evaluate(top_X_test,top_y_test)
print("Test Accuracy:", top_test_accuracy)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0757 - accuracy: 0.9737
# Test Accuracy: 0.9736841917037964

# %%
top_loss=(1-top_test_accuracy)*100
print("The error of ANN is : ",top_loss,"in percentage")
# Out:
# The error of ANN is :  2.6315808296203613 in percentage

# %%
top_predictions=model.predict(X_test)
top_predictions_classes=np.argmax(top_predictions,axis=1)
classification_report_top=classification_report(y_test,top_predictions_classes)
print(classification_report_top)
# Out:
# 4/4 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        72
#            1       0.95      0.95      0.95        42
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.96      0.96       114
# weighted avg       0.96      0.96      0.96       114

# %%
#Now let us apply PCA
#Principal Component Analysis
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
import numpy as np
cov_matrix=np.cov(X_scaled, rowvar=False)

# %%
#calculate the Eigen Value and Eigen Vector
eigenvalues, eigenvectors= np.linalg.eig(cov_matrix)

# %%
#sort the eigen values and select the Principal components
sorted_index=np.argsort(eigenvalues)[::-1]
sorted_eigenvalues= eigenvalues[sorted_index]
sorted_eigenvectors=eigenvectors[:, sorted_index]
#select the top 16 eigenvectors and eigenvalues
num_components=16
principal_components= sorted_eigenvectors[:, :num_components]

# %%
X_pca=X_scaled.dot(principal_components)

# %%
X_pca
# Out:
# array([[ 9.19158131,  1.95414096, -1.12040975, ...,  0.69352554,
#         -0.61082922,  0.73658206],
#        [ 2.48468989, -3.82334657, -0.46931418, ...,  0.67772356,
#          0.11441041, -0.79600801],
#        [ 5.73377666, -1.07389677, -0.55151553, ..., -0.0166804 ,
#          0.47962415,  0.32826728],
#        ...,
#        [ 1.25673726, -1.90469894,  0.56077836, ..., -0.28923481,
#          0.09376035, -0.22964867],
#        [10.37479296,  1.67122199, -1.87891239, ..., -0.21945505,
#          0.23092736, -0.05908333],
#        [-5.47484657, -0.67385059,  1.48851698, ...,  1.16677003,
#          0.20630911,  0.92543393]])

# %%
from sklearn.model_selection import train_test_split
seed_value=42
X_train_pca, X_test_pca, y_train_pca, y_test_pca=train_test_split(X_pca,y,test_size=0.2,random_state=seed_value)

# %%
#let us apply Decision Tree
from sklearn.tree import DecisionTreeClassifier
pca_dtree=DecisionTreeClassifier(random_state=42)

# %%
pca_dtree.fit(X_train_pca,y_train_pca)
y_pred_pca=pca_dtree.predict(X_test_pca)

# %%
from sklearn.metrics import accuracy_score, classification_report
accuracy_dtree_pca=accuracy_score(y_test_pca,y_pred_pca)
classification_dtree_pca=classification_report(y_test_pca, y_pred_pca)

# %%
print("Accuracy: ",accuracy_dtree_pca)
print("Classification_report: ")
print(classification_dtree_pca)
# Out:
# Accuracy:  0.956140350877193
# Classification_report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96        71
#            1       0.93      0.95      0.94        43
#
#     accuracy                           0.96       114
#    macro avg       0.95      0.96      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %%
error_rate_dtree_pca=(1-accuracy_dtree_pca)*100
print(error_rate_dtree_pca)
# Out:
# 4.385964912280704

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
pca_Rforest=RandomForestClassifier(random_state=42)
pca_Rforest.fit(X_train_pca,y_train_pca)
pca_y_pred=pca_Rforest.predict(X_test_pca)

# %%
from sklearn.metrics import accuracy_score, classification_report
accuracy_RF_pca=accuracy_score(y_test_pca,y_pred_pca)
classification_RF_pca=classification_report(y_test_pca, y_pred_pca)

# %%
print("Accuracy: ",accuracy_RF_pca)
print("Classification_report: ")
print(classification_RF_pca)
# Out:
# Accuracy:  0.956140350877193
# Classification_report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96        71
#            1       0.93      0.95      0.94        43
#
#     accuracy                           0.96       114
#    macro avg       0.95      0.96      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %%
error_rate_RF_PCA=(1-accuracy_RF_pca)*100
print(error_rate_RF_PCA)
# Out:
# 4.385964912280704

# %%
#svm
seed_value=42
from sklearn.svm import SVC
pca_svm=SVC(kernel='linear', random_state=seed_value)
pca_svm.fit(X_train_pca, y_train_pca)
y_pred=pca_svm.predict(X_test_pca)

# %%
from tensorflow.python.framework.ops import add_exit_callback_to_default_func_graph
accuracy_svm_pca=accuracy_score(y_test_pca,y_pred)
classification_svm_pca=classification_report(y_test_pca,y_pred)
error_rate_svm_pca=(1-accuracy_svm_pca)*100

# %%
print("Accuracy of SVM for 16 features: ",accuracy_svm_pca)
print('Classfication of SVM for 16 features: ')
print(classification_svm_pca)
print("Error rate for svm classifier: ",error_rate_svm_pca)
# Out:
# Accuracy of SVM for 16 features:  0.9824561403508771
# Classfication of SVM for 16 features:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        71
#            1       0.98      0.98      0.98        43
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# Error rate for svm classifier:  1.7543859649122862

# %%
#logistic regression
seed_value=42
from sklearn.linear_model import LogisticRegression
pca_log_reger=LogisticRegression(random_state=seed_value)
pca_log_reger.fit(X_train_pca,y_train_pca)
# Out:
# LogisticRegression(random_state=42)

# %%
y_pred=pca_log_reger.predict(X_test_pca)

# %%
from sklearn.metrics import accuracy_score, classification_report
accuracy_log_pca1=accuracy_score(y_test_pca,y_pred_pca)
classification_log_pca1=classification_report(y_test_pca, y_pred_pca)
error_rate_log_pca1=(1-accuracy_log_pca1)*100

# %%
print("Accuracy of logsitic regression for 16 features: ",accuracy_log_pca1)
print('Classfication of SVM for 16 features: ')
print(classification_log_pca1)
print("Error rate for svm classifier: ",error_rate_log_pca1)
# Out:
# Accuracy of logsitic regression for 16 features:  0.956140350877193
# Classfication of SVM for 16 features:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96        71
#            1       0.93      0.95      0.94        43
#
#     accuracy                           0.96       114
#    macro avg       0.95      0.96      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
# Error rate for svm classifier:  4.385964912280704

# %%
#let us now Arrificial Neural Network
import tensorflow as tf
import numpy as np
import random
from tensorflow import keras
seed_value=42
input_dim=X_train_pca.shape[1]
num_classes=2

# Set random seeds for reproducibility
seed_value = 42
tf.random.set_seed(seed_value)
np.random.seed(seed_value)
random.seed(seed_value)


pca_model = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(input_dim,), name='input_layer'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(128, activation='relu', name='hidden_layer_1'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(num_classes, activation='softmax', name='output_layer')
])
pca_model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
pca_model.fit(X_train_pca,y_train_pca,epochs=10,batch_size=32, validation_data=(X_train_pca,y_train_pca),verbose=2)
# Out:
# Epoch 1/10
# 15/15 - 1s - loss: 0.7164 - accuracy: 0.5956 - val_loss: 0.3479 - val_accuracy: 0.9297 - 1s/epoch - 74ms/step
# Epoch 2/10
# 15/15 - 0s - loss: 0.3878 - accuracy: 0.8527 - val_loss: 0.2195 - val_accuracy: 0.9429 - 116ms/epoch - 8ms/step
# Epoch 3/10
# 15/15 - 0s - loss: 0.2675 - accuracy: 0.9099 - val_loss: 0.1662 - val_accuracy: 0.9538 - 87ms/epoch - 6ms/step
# Epoch 4/10
# 15/15 - 0s - loss: 0.2074 - accuracy: 0.9297 - val_loss: 0.1408 - val_accuracy: 0.9582 - 113ms/epoch - 8ms/step
# Epoch 5/10
# 15/15 - 0s - loss: 0.1731 - accuracy: 0.9429 - val_loss: 0.1251 - val_accuracy: 0.9604 - 72ms/epoch - 5ms/step
# Epoch 6/10
# 15/15 - 0s - loss: 0.1543 - accuracy: 0.9429 - val_loss: 0.1090 - val_accuracy: 0.9692 - 113ms/epoch - 8ms/step
# Epoch 7/10
# 15/15 - 0s - loss: 0.1435 - accuracy: 0.9538 - val_loss: 0.0929 - val_accuracy: 0.9802 - 69ms/epoch - 5ms/step
# Epoch 8/10
# ...

# %%
test_loss_ann_pca1,test_ann_accuracy_pca1=pca_model.evaluate(X_test_pca,y_test_pca)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0637 - accuracy: 0.9737

# %%
predictions_ann_pca1=pca_model.predict(X_test_pca)
predicted_classes_ann_pca1 = np.argmax(predictions_ann_pca1, axis=1)
print(classification_report(y_test_pca,predicted_classes_ann_pca1))
# Out:
# 4/4 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98        71
#            1       0.95      0.98      0.97        43
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %%
error_rate_ann_pca1=(1-test_ann_accuracy_pca1)*100
print(error_rate_ann_pca1)
# Out:
# 2.6315808296203613

# %%
#KNN FOR PCA WITH FEATURES 16
from sklearn.neighbors import KNeighborsClassifier
knn_pca1=KNeighborsClassifier(n_neighbors=3)
knn_pca1.fit(X_train_pca,y_train_pca)
y_pred_knn_pca1=knn_pca1.predict(X_test_pca)
accuracy_pca1=accuracy_score(y_test_pca,y_pred_knn_pca1)
print("Accuracy of knn with 16 features: ",accuracy_pca1)
error_knn_pca1=(1-accuracy_pca1)*100
print("Error rate of pca with 16 features: ",error_knn_pca1)
classification_report_knn=classification_report(y_test_pca,y_pred_knn_pca1)
print(classification_report_knn)
# Out:
# Accuracy of knn with 16 features:  0.9473684210526315
# Error rate of pca with 16 features:  5.263157894736848
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        71
#            1       0.93      0.93      0.93        43
#
#     accuracy                           0.95       114
#    macro avg       0.94      0.94      0.94       114
# weighted avg       0.95      0.95      0.95       114

# %% [markdown]
# LET US APPLY PCA FOR 8 FEATURES

# %%
#Now let us apply PCA
#Principal Component Analysis
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scaled=scaler.fit_transform(X)
import numpy as np
cov_matrix_8=np.cov(X_scaled, rowvar=False)
#calculate the Eigen Value and Eigen Vector
eigenvalues_8, eigenvectors_8= np.linalg.eig(cov_matrix_8)
#sort thr eigen values and select the Principal components
sorted_index_8=np.argsort(eigenvalues_8)[::-1]
sorted_eigenvalues_8= eigenvalues_8[sorted_index]
sorted_eigenvectors_8=eigenvectors_8[:, sorted_index]
#select the top 16 eigenvectors and eigenvalues
num_components=8
principal_components_8= sorted_eigenvectors_8[:, :num_components]

# %%
X_pca_8=X_scaled.dot(principal_components)

# %%
from sklearn.model_selection import train_test_split
seed_value=42
X_train_pca_8, X_test_pca_8, y_train_pca_8, y_test_pca_8=train_test_split(X_pca_8,y,test_size=0.2,random_state=seed_value)

# %%
#DECISION TREE
from sklearn.tree import DecisionTreeClassifier
seed_value=42
dtree8= DecisionTreeClassifier(random_state=seed_value)
dtree8.fit(X_train_pca_8,y_train_pca_8)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_dtree_pca_8=dtree8.predict(X_test_pca_8)

# %%
accuracy_dtree_pca_8=accuracy_score(y_test_pca_8,y_pred_dtree_pca_8)
classification_dtree_pca_8=classification_report(y_test_pca_8,y_pred_dtree_pca_8)

# %%
print("Accuracy: ",accuracy_dtree_pca_8)
print("Classfication report: ")
print(classification_dtree_pca_8)
error_rate_dtree_pca_8=(1-accuracy_dtree_pca_8)*100
print("Error rate: ",error_rate_dtree_pca_8)
# Out:
# Accuracy:  0.956140350877193
# Classfication report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96        71
#            1       0.93      0.95      0.94        43
#
#     accuracy                           0.96       114
#    macro avg       0.95      0.96      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
# Error rate:  4.385964912280704

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier
seed_value=42
rforest8=RandomForestClassifier(random_state=seed_value)
rforest8.fit(X_train_pca_8,y_train_pca_8)
y_pred_rf8=rforest8.predict(X_test_pca_8)

# %%
r_accuracy=accuracy_score(y_test_pca_8,y_pred_rf8)
r_classification=classification_report(y_test_pca_8,y_pred_rf8)
r_error_rate=(1-r_accuracy)*100

# %%
print("Accuracy: ",r_accuracy)
print("Classification Report: ")
print(r_classification)
print("Error rate in pecentage: ",r_error_rate)
# Out:
# Accuracy:  0.956140350877193
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96        71
#            1       0.93      0.95      0.94        43
#
#     accuracy                           0.96       114
#    macro avg       0.95      0.96      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
# Error rate in pecentage:  4.385964912280704

# %%
#SVM
from sklearn.svm import SVC
svm_classifier_8=SVC(kernel='linear',random_state=42)
svm_classifier_8.fit(X_train_pca_8,y_train_pca_8)
y_pred_s=svm_classifier_8.predict(X_test_pca_8)

# %%
s_accuracy=accuracy_score(y_test_pca_8,y_pred_s)
s_classification=classification_report(y_test_pca_8,y_pred_s)
s_error=(1-s_accuracy)*100

# %%
print("Accuracy of SVM for 16 features: ",s_accuracy)
print("Accuracy of SVM for 16 features: ")
print(s_classification)
print("Accuracy of SVM for 16 features: ",s_error)

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
log_reger_8=LogisticRegression(random_state=seed_value)
log_reger_8.fit(X_train_pca_8,y_train_pca_8)
l_y_pred=log_reger_8.predict(X_test_pca_8)

# %%
l_accuracy=accuracy_score(l_y_pred,y_test_pca_8)
l_classification=classification_report(l_y_pred,y_test_pca_8)
l_error_rate=(1-l_accuracy)*100

# %%
print("Accurcay: ",l_accuracy)
print("Classification of Logistic Regression: ")
print(l_classification)
print("Error rate: ")
print(l_error_rate)
# Out:
# Accurcay:  0.9912280701754386
# Classification of Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99        72
#            1       0.98      1.00      0.99        42
#
#     accuracy                           0.99       114
#    macro avg       0.99      0.99      0.99       114
# weighted avg       0.99      0.99      0.99       114
#
# Error rate:
# 0.8771929824561431

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier
knn_classifier_8=KNeighborsClassifier(n_neighbors=3)
knn_classifier_8.fit(X_train_pca_8,y_train_pca_8)
knn_y_pred8=knn_classifier_8.predict(X_test_pca_8)

# %%
knn_accuracy_8=accuracy_score(y_test_pca_8,knn_y_pred8)
knn_classification8=classification_report(y_test_pca_8,knn_y_pred8)
knn_error_rate8=(1-knn_accuracy_8)*100

# %%
print("Accuracy of KNN at 8 features: ",knn_accuracy_8)
print("Classification of KNN at 8 features: ")
print(knn_classification8)
print("Error rate of KNN classifier at 8 fetures: ",knn_error_rate8)
# Out:
# Accuracy of KNN at 8 features:  0.9473684210526315
# Classification of KNN at 8 features:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        71
#            1       0.93      0.93      0.93        43
#
#     accuracy                           0.95       114
#    macro avg       0.94      0.94      0.94       114
# weighted avg       0.95      0.95      0.95       114
#
# Error rate of KNN classifier at 8 fetures:  5.263157894736848

# %%
#ANN
import tensorflow as tf
import numpy as np
import random
from tensorflow import keras
seed_value=42
tf.random.set_seed(seed_value)
np.random.seed(seed_value)

#defining the neural network
input_dim=X_train_pca_8.shape[1]
num_classes=2

new_model_pca_8=keras.Sequential([
    keras.layers.Dense(64,activation='relu',input_shape=(input_dim,),name='input_layer'),
    #keras.Dropout(0.5),
    keras.layers.Dense(128,activation='relu',name='hidden_layer_1'),
    #keras.Dropout(0.5),
    keras.layers.Dense(num_classes, activation='softmax', name='output_layer')
])

#compiling the model
new_model_pca_8.compile(optimizer='adam',
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])

new_model_pca_8.fit(X_train_pca_8,y_train_pca_8, epochs=10, batch_size=32, validation_data=(X_test_pca_8,y_test_pca_8),verbose=2)

test_loss_8,test_accuracy_8=new_model_pca_8.evaluate(X_test_pca_8,y_test_pca_8)
print("Test Accuracy: ",test_accuracy_8)
print("Test Loss: ",test_loss_8)
# Out:
# Epoch 1/10
# 15/15 - 1s - loss: 0.4392 - accuracy: 0.8484 - val_loss: 0.2033 - val_accuracy: 0.9649 - 862ms/epoch - 57ms/step
# Epoch 2/10
# 15/15 - 0s - loss: 0.1853 - accuracy: 0.9538 - val_loss: 0.1105 - val_accuracy: 0.9737 - 41ms/epoch - 3ms/step
# Epoch 3/10
# 15/15 - 0s - loss: 0.1206 - accuracy: 0.9714 - val_loss: 0.0849 - val_accuracy: 0.9737 - 54ms/epoch - 4ms/step
# Epoch 4/10
# 15/15 - 0s - loss: 0.0898 - accuracy: 0.9802 - val_loss: 0.0711 - val_accuracy: 0.9825 - 63ms/epoch - 4ms/step
# Epoch 5/10
# 15/15 - 0s - loss: 0.0728 - accuracy: 0.9802 - val_loss: 0.0631 - val_accuracy: 0.9825 - 56ms/epoch - 4ms/step
# Epoch 6/10
# 15/15 - 0s - loss: 0.0624 - accuracy: 0.9824 - val_loss: 0.0610 - val_accuracy: 0.9737 - 57ms/epoch - 4ms/step
# Epoch 7/10
# 15/15 - 0s - loss: 0.0562 - accuracy: 0.9846 - val_loss: 0.0632 - val_accuracy: 0.9737 - 44ms/epoch - 3ms/step
# Epoch 8/10
# ...

# %%
ann_error_rate=(1-test_accuracy_8)*100
print("Eror rate of ANN in percentage: ",ann_error_rate)
# Out:
# Eror rate of ANN in percentage:  2.6315808296203613

# %%
predictions_whole8=new_model_pca_8.predict(X_test_pca_8)
predicted_classes_whole8 = np.argmax(predictions_whole8, axis=1)
print(classification_report(y_test_pca_8,predicted_classes_whole8))
# Out:
# 4/4 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        71
#            1       0.98      0.95      0.96        43
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %% [markdown]
# PCA ANALYSIS FOR 4 FEATURES

# %%
#Now let us apply PCA
#Principal Component Analysis for 4 Features
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scaled_4=scaler.fit_transform(X)
import numpy as np
cov_matrix_4=np.cov(X_scaled_4, rowvar=False)
#calculate the Eigen Value and Eigen Vector
eigenvalues_4, eigenvectors_4= np.linalg.eig(cov_matrix_4)
#sort thr eigen values and select the Principal components
sorted_index_4=np.argsort(eigenvalues_4)[::-1]
sorted_eigenvalues_4= eigenvalues_4[sorted_index_4]
sorted_eigenvectors_4=eigenvectors_4[:, sorted_index_4]
#select the top 4 eigenvectors and eigenvalues
num_components=4
principal_components_4= sorted_eigenvectors_4[:, :num_components]

# %%
X_pca_4=X_scaled_4.dot(principal_components_4)

# %%
from sklearn.model_selection import train_test_split
seed_value=42
X_train_pca_4, X_test_pca_4, y_train_pca_4, y_test_pca_4=train_test_split(X_pca_4,y,test_size=0.2,random_state=seed_value)

# %%
from sklearn.tree import DecisionTreeClassifier
seed_value=42
dtree_4=DecisionTreeClassifier(random_state=seed_value)
dtree_4.fit(X_train_pca_4,y_train_pca_4)
dt_y_pred=dtree_4.predict(X_test_pca_4)

# %%
from sklearn.metrics import accuracy_score,classification_report
dt_accuracy=accuracy_score(y_test_pca_4,dt_y_pred)
dt_classification=classification_report(y_test_pca_4,dt_y_pred)
dt_error_rate=(1-dt_accuracy)*100

# %%
print("Accuracy :",dt_accuracy)
print("Classification Report: ")
print(dt_classification)
print("Error Rate: ")
print(dt_error_rate)

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier
seed_value=42
rf_classifier=RandomForestClassifier(random_state=seed_value)
rf_classifier.fit(X_train_pca_4,y_train_pca_4)
rf_y_pred=rf_classifier.predict(X_test_pca_4)

# %%
rf_accuracy_score=accuracy_score(y_test_pca_4,rf_y_pred)
rf_classification=classification_report(y_test_pca_4,rf_y_pred)
error_rate_4=(1-rf_accuracy_score)*100

# %%
print("Accuracy: ",rf_accuracy_score)
print("Classification report: ")
print(rf_classification)
print("Error rate: ",error_rate_4," in percentage")

# %%
#svm
from sklearn.svm import SVC
seed_value=42
svm_class_4=SVC(kernel="linear",random_state=seed_value)
svm_class_4.fit(X_train_pca_4,y_train_pca_4)
svm_y_pred_4=svm_class_4.predict(X_test_pca_4)

# %%
svm_accuracy_score4=accuracy_score(y_test_pca_4,svm_y_pred_4)
svm_classification4=classification_report(y_test_pca_4,svm_y_pred_4)
svm_error_rate4=(1-svm_accuracy_score4)*100

# %%
print("Accuracy: ",svm_accuracy_score4)
print("Classification report: ")
print(svm_classification4)
print("Error rate: ",svm_error_rate4," in percentage")

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
seed_value=42
log_reger_4=LogisticRegression(random_state=seed_value)
log_reger_4.fit(X_train_pca_4,y_train_pca_4)
log_reger_y_pred_4=log_reger_4.predict(X_test_pca_4)

# %%
log_accuracy_4=accuracy_score(y_test_pca_4,log_reger_y_pred_4)
log_classification_4=classification_report(y_test_pca_4,log_reger_y_pred_4)
log_error_4=(1-log_accuracy_4)*100

# %%
print("Accuracy Score: ",log_accuracy_4)
print("Classificatiob Report: ")
print(log_classification_4)
print("Error Rate: ",log_error_4)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_classifier_4=KNeighborsClassifier(n_neighbors=3)
knn_classifier_4.fit(X_train_pca_4,y_train_pca_4)
knn_y_pred_4=knn_classifier_4.predict(X_test_pca_4)

# %%
accuracy_score_4=accuracy_score(knn_y_pred_4,y_test_pca_4)
knn_classification_4=classification_report(knn_y_pred_4,y_test_pca_4)
knn_error_rate_4=(1-accuracy_score_4)*100

# %%
print("Accuracy: ",accuracy_score_4)
print("Classification: ",knn_classification_4)
print("Error rate: ")
print(knn_error_rate_4)

# %%
#ANN
import tensorflow as tf
import numpy as np
import random
from tensorflow import keras
seed_value=42
tf.random.set_seed(seed_value)
np.random.seed(seed_value)

#defining the neural network
input_dim=X_train_pca_4.shape[1]
num_classes=2

new_model_pca_4=keras.Sequential([
    keras.layers.Dense(64,activation='relu',input_shape=(input_dim,),name='input_layer'),
    #keras.Dropout(0.5),
    keras.layers.Dense(128,activation='relu',name='hidden_layer_1'),
    #keras.Dropout(0.5),
    keras.layers.Dense(num_classes, activation='softmax', name='output_layer')
])

#compiling the model
new_model_pca_4.compile(optimizer='adam',
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])

new_model_pca_4.fit(X_train_pca_4,y_train_pca_4, epochs=15, batch_size=32, validation_data=(X_test_pca_4,y_test_pca_4),verbose=2)

test_loss_4,test_accuracy_4=new_model_pca_4.evaluate(X_test_pca_4,y_test_pca_4)
print("Test Accuracy: ",test_accuracy_4)
print("Test Loss: ",test_loss_4)

# %%
ann_error_rate_4=(1-test_accuracy_4)*100
print("Ann Error Rate: ",ann_error_rate_4)

# %%
predictions_whole4=new_model_pca_4.predict(X_test_pca_4)
predicted_classes_whole4 = np.argmax(predictions_whole4, axis=1)
print(classification_report(y_test_pca_4,predicted_classes_whole4))

# %% [markdown]
# PCA ANALYSIS FOR 2 FEATURES

# %%
#Now let us apply PCA
#Principal Component Analysis for 4 Features
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scaled_2=scaler.fit_transform(X)
import numpy as np
cov_matrix_2=np.cov(X_scaled_2, rowvar=False)
#calculate the Eigen Value and Eigen Vector
eigenvalues_2, eigenvectors_2= np.linalg.eig(cov_matrix_2)
#sort thr eigen values and select the Principal components
sorted_index_2=np.argsort(eigenvalues_2)[::-1]
sorted_eigenvalues_2= eigenvalues_2[sorted_index_2]
sorted_eigenvectors_2=eigenvectors_2[:, sorted_index_2]
#select the top 2 eigenvectors and eigenvalues
num_components=2
principal_components_2= sorted_eigenvectors_2[:, :num_components]

# %%
X_pca_2=X_scaled_2.dot(principal_components_2)

# %%
from sklearn.model_selection import train_test_split
seed_value=42
X_train_pca_2, X_test_pca_2, y_train_pca_2, y_test_pca_2=train_test_split(X_pca_2,y,test_size=0.2,random_state=seed_value)

# %%
X_pca_2

# %% [markdown]
# LET US APPLY PREDICTIVE MODELS

# %%
from sklearn.tree import DecisionTreeClassifier
seed_value=42
dtree_2=DecisionTreeClassifier(random_state=seed_value)
dtree_2.fit(X_train_pca_2,y_train_pca_2)
y_pred_2=dtree_2.predict(X_test_pca_2)

# %%
dt_accuracy_score_2=accuracy_score(y_test_pca_2,y_pred_2)
classification_2=classification_report(y_test_pca_2,y_pred_2)
dt_error_rate_2=(1-dt_accuracy_score_2)*100

# %%
print("Accuracy: ",dt_accuracy_score_2)
print("Classification Report: ")
print(classification_2)
print(dt_error_rate_2)

# %%
#RandomForest Classifier
from sklearn.ensemble import RandomForestClassifier
seed_value=42
rf_classifier_2=RandomForestClassifier(random_state=seed_value)
rf_classifier_2.fit(X_train_pca_2,y_train_pca_2)
rf_y_pred_2=rf_classifier_2.predict(X_test_pca_2)

# %%
rf_accuracy_score_2=accuracy_score(y_test_pca_2,rf_y_pred_2)
rf_classification_2=classification_report(y_test_pca_2,rf_y_pred_2)
rf_error_2=(1-rf_accuracy_score_2)*100

# %%
print("Accuracy: ",rf_accuracy_score_2)
print("Classification Report: ")
print(rf_classification_2)
print(rf_error_2)

# %%
#SVM
from sklearn.svm import SVC
seed_value=42
svm_classifier_2=SVC(kernel='linear',random_state=seed_value)
svm_classifier_2.fit(X_train_pca_2,y_train_pca_2)
svm_y_pred_2=svm_classifier_2.predict(X_test_pca_2)

# %%
svm_accuracy_score_2=accuracy_score(y_test_pca_2,svm_y_pred_2)
svm_classification_2=classification_report(y_test_pca_2,svm_y_pred_2)
svm_error_rate_2=(1-svm_accuracy_score_2)*100

# %%
print("Accuracy Score: ",svm_accuracy_score_2)
print("CLssification report:")
print(svm_classification_2)
print("Eror rate: ",svm_error_rate_2,"in percentage")

# %%
#logistic Regression
from sklearn.linear_model import LogisticRegression
log_reger_2=LogisticRegression(random_state=seed_value)
log_reger_2.fit(X_train_pca_2,y_train_pca_2)
log_y_pred_2=log_reger_2.predict(X_test_pca_2)

# %%
log_accuracy_score_2=accuracy_score(y_test_pca_2,log_y_pred_2)
log_classification_2=classification_report(y_test_pca_2,log_y_pred_2)
log_error_2=(1-log_accuracy_score_2)*100

# %%
print("Accuracy: ",log_accuracy_score_2)
print("Classification report: ")
print(log_classification_2)
print("Error rate: ",log_error_2)

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier
knn_classifier_2=KNeighborsClassifier(n_neighbors=3)
knn_classifier_2.fit(X_train_pca_2,y_train_pca_2)
knn_y_pred_2=knn_classifier_2.predict(X_test_pca_2)

# %%
knn_accuracy_2=accuracy_score(y_test_pca_2,knn_y_pred_2)
knn_classification_2=classification_report(y_test_pca_2,knn_y_pred_2)
knn_error_2=(1-knn_accuracy_2)*100

# %%
print("Accuracy: ",knn_accuracy_2)
print("Classification report: ")
print(knn_classification_2)
print("Error ",knn_error_2,"in percentage")

# %%
#ANN
import tensorflow as tf
import numpy as np
import random
from tensorflow import keras
seed_value=42
tf.random.set_seed(seed_value)
np.random.seed(seed_value)

#defining the neural network
input_dim_2=X_train_pca_2.shape[1]
num_classes=2

new_model_pca_2=keras.Sequential([
    keras.layers.Dense(64,activation='relu',input_shape=(input_dim_2,),name='input_layer'),
    #keras.Dropout(0.5),
    keras.layers.Dense(128,activation='relu',name='hidden_layer_1'),
    #keras.Dropout(0.5),
    keras.layers.Dense(num_classes, activation='softmax', name='output_layer')
])

#compiling the model
new_model_pca_2.compile(optimizer='adam',
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])

new_model_pca_2.fit(X_train_pca_2,y_train_pca_2, epochs=15, batch_size=32, validation_data=(X_test_pca_2,y_test_pca_2),verbose=2)

test_loss_2,test_accuracy_2=new_model_pca_2.evaluate(X_test_pca_2,y_test_pca_2)
print("Test Accuracy: ",test_accuracy_2)
print("Test Loss: ",test_loss_2)

# %%
ann_error_rate_2=(1-test_accuracy_2)*100
print("Ann Error Rate: ",ann_error_rate_2)

# %%
predictions_whole2=new_model_pca_2.predict(X_test_pca_2)
predicted_classes_whole2 = np.argmax(predictions_whole2, axis=1)
print(classification_report(y_test_pca_2,predicted_classes_whole2))
